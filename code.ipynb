# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Your sentence
sentence = ["He is a young man with golden hair and brown eyes"]

# Your word groups
word_groups = [
    "blonde hair",
    "blue eyes",
    "male"
    # Add more groups as needed
]

# All documents
documents = sentence + word_groups

# Create the TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Calculate TF-IDF vectors for all documents
tfidf_matrix = vectorizer.fit_transform(documents)

# Get the TF-IDF vector for the sentence
sentence_vector = tfidf_matrix[0]

# Calculate cosine similarity between the sentence and each word group
similarities = cosine_similarity(sentence_vector, tfidf_matrix[1:])

# Print the similarity scores
for i, similarity in enumerate(similarities[0]):
    print(f"Similarity of sentence with word group {i+1}: {similarity}")
# Out:
# Similarity of sentence with word group 1: 0.1605551232432008
# Similarity of sentence with word group 2: 0.1605551232432008
# Similarity of sentence with word group 3: 0.0

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\yuceelege\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in c:\users\yuceelege\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Collecting huggingface-hub<1.0,>=0.14.1
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\yuceelege\anaconda3\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\yuceelege\anaconda3\lib\site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: packaging>=20.0 in c:\users\yuceelege\anaconda3\lib\site-packages (from transformers) (21.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-win_amd64.whl (3.5 MB)
# Requirement already satisfied: requests in c:\users\yuceelege\anaconda3\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\yuceelege\anaconda3\lib\site-packages (from transformers) (1.21.5)
# Requirement already satisfied: fsspec in c:\users\yuceelege\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2022.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\yuceelege\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\yuceelege\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: colorama in c:\users\yuceelege\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yuceelege\anaconda3\lib\site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\yuceelege\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yuceelege\anaconda3\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yuceelege\anaconda3\lib\site-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.29.2

# %%
from nltk.corpus import wordnet
from random import choice, randint
import random
import openai
import csv
openai.api_key = "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"  # Replace with your OpenAI API key

features = ["5_o_Clock_Shadow","Arched_Eyebrows","Attractive","Bags_Under_Eyes","Bald", "Bangs","Big_Lips","Big_Nose",
            "Black_Hair","Blond_Hair","Blurry","Brown_Hair","Bushy_Eyebrows","Chubby","Double_Chin","Eyeglasses","Goatee",
            "Gray_Hair", "Heavy_Makeup","High_Cheekbones","Male","Mouth_Slightly_Open","Mustache","Narrow_Eyes","No_Beard",
            "Oval_Face","Pale_Skin","Pointy_Nose","Receding_Hairline","Rosy_Cheeks","Sideburns","Smiling","Straight_Hair",
            "Wavy_Hair","Wearing_Earrings","Wearing_Hat","Wearing_Lipstick","Wearing_Necklace","Wearing_Necktie","Young"]

def get_synonyms(word):
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    return list(synonyms)

def generate_sentence_template():
    num_features = random.randint(3, 5)  # choose a random number of features
    chosen_features = random.sample(features, num_features)  # choose random features

    prompt = "Generate a single sentence template describing a person with unique sentences with the following features: "
    prompt += ", ".join(chosen_features) + "."
    prompt += "Dont just write features next to each other as it is. Use a unique sentence structure and with different types of expressions. You may sometimes use synonyms."

    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        temperature=0.7,
        max_tokens=50,
        top_p=0.9,
        n=1
    )

    template = response.choices[0].text.strip()
    return template, chosen_features

# Generate sentences and store them in a CSV file
output_file = "sentences.csv"

with open(output_file, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["sentence"] + features)  # Write column headers
    count = 0
    for _ in range(3000):  # Generate 10 sentences
        count +=1
        template, chosen_features = generate_sentence_template()

        # Process the chosen features and their synonyms
        feature_synonyms = {}
        for feature in chosen_features:
            synonyms = get_synonyms(feature)
            if synonyms:
                feature_synonyms[feature] = synonyms

        # Create the sentence using the template and the chosen features/synonyms
        sentence = template
        feature_values = []
        for feature in features:
            if feature in chosen_features:
                value = 1
            else:
                value = 0
            feature_values.append(value)

        writer.writerow([sentence] + feature_values)
        print("Sentence {} completed".format(count))
# Out:
# Sentence 1 completed
# Sentence 2 completed
# Sentence 3 completed
# Sentence 4 completed
# Sentence 5 completed
# Sentence 6 completed
# Sentence 7 completed
# Sentence 8 completed
# Sentence 9 completed
# Sentence 10 completed
# Sentence 11 completed
# Sentence 12 completed
# Sentence 13 completed
# Sentence 14 completed
# Sentence 15 completed
# Sentence 16 completed
# Sentence 17 completed
# Sentence 18 completed
# Sentence 19 completed
# Sentence 20 completed
# Sentence 21 completed
# Sentence 22 completed
# Sentence 23 completed
# Sentence 24 completed
# Sentence 25 completed
# Sentence 26 completed
# Sentence 27 completed
# Sentence 28 completed
# Sentence 29 completed
# Sentence 30 completed
# Sentence 31 completed
# Sentence 32 completed
# Sentence 33 completed
# Sentence 34 completed
# Sentence 35 completed
# Sentence 36 completed
# Sentence 37 completed
# Sentence 38 completed
# Sentence 39 completed
# Sentence 40 completed
# Sentence 41 completed
# Sentence 42 completed
# Sentence 43 completed
# Sentence 44 completed
# Sentence 45 completed
# Sentence 46 completed
# Sentence 47 completed
# Sentence 48 completed
# Sentence 49 completed
# Sentence 50 completed
# Sentence 51 completed
# Sentence 52 completed
# Sentence 53 completed
# Sentence 54 completed
# Sentence 55 completed
# Sentence 56 completed
# Sentence 57 completed
# Sentence 58 completed
# Sentence 59 completed
# Sentence 60 completed
# Sentence 61 completed
# Sentence 62 completed
# Sentence 63 completed
# Sentence 64 completed
# Sentence 65 completed
# Sentence 66 completed
# Sentence 67 completed
# Sentence 68 completed
# Sentence 69 completed
# Sentence 70 completed
# Sentence 71 completed
# Sentence 72 completed
# Sentence 73 completed
# Sentence 74 completed
# Sentence 75 completed
# Sentence 76 completed
# Sentence 77 completed
# Sentence 78 completed
# Sentence 79 completed
# Sentence 80 completed
# Sentence 81 completed
# Sentence 82 completed
# Sentence 83 completed
# Sentence 84 completed
# Sentence 85 completed
# Sentence 86 completed
# Sentence 87 completed
# Sentence 88 completed
# Sentence 89 completed
# Sentence 90 completed
# Sentence 91 completed
# Sentence 92 completed
# Sentence 93 completed
# Sentence 94 completed
# Sentence 95 completed
# Sentence 96 completed
# Sentence 97 completed
# Sentence 98 completed
# Sentence 99 completed
# Sentence 100 completed
# Sentence 101 completed
# Sentence 102 completed
# Sentence 103 completed
# Sentence 104 completed
# Sentence 105 completed
# Sentence 106 completed
# Sentence 107 completed
# Sentence 108 completed
# Sentence 109 completed
# Sentence 110 completed
# Sentence 111 completed
# Sentence 112 completed
# Sentence 113 completed
# Sentence 114 completed
# Sentence 115 completed
# Sentence 116 completed
# Sentence 117 completed
# Sentence 118 completed
# Sentence 119 completed
# Sentence 120 completed
# Sentence 121 completed
# Sentence 122 completed
# Sentence 123 completed
# Sentence 124 completed
# Sentence 125 completed
# Sentence 126 completed
# Sentence 127 completed
# Sentence 128 completed
# Sentence 129 completed
# Sentence 130 completed
# Sentence 131 completed
# Sentence 132 completed
# Sentence 133 completed
# Sentence 134 completed
# Sentence 135 completed
# Sentence 136 completed
# Sentence 137 completed
# Sentence 138 completed
# Sentence 139 completed
# Sentence 140 completed
# Sentence 141 completed
# Sentence 142 completed
# Sentence 143 completed
# Sentence 144 completed
# Sentence 145 completed
# Sentence 146 completed
# Sentence 147 completed
# Sentence 148 completed
# Sentence 149 completed
# Sentence 150 completed
# Sentence 151 completed
# Sentence 152 completed
# Sentence 153 completed
# Sentence 154 completed
# Sentence 155 completed
# Sentence 156 completed
# Sentence 157 completed
# Sentence 158 completed
# Sentence 159 completed
# Sentence 160 completed
# Sentence 161 completed
# Sentence 162 completed
# Sentence 163 completed
# Sentence 164 completed
# Sentence 165 completed
# Sentence 166 completed
# Sentence 167 completed
# Sentence 168 completed
# Sentence 169 completed
# Sentence 170 completed
# Sentence 171 completed
# Sentence 172 completed
# Sentence 173 completed
# Sentence 174 completed
# Sentence 175 completed
# Sentence 176 completed
# Sentence 177 completed
# Sentence 178 completed
# Sentence 179 completed
# Sentence 180 completed
# Sentence 181 completed
# Sentence 182 completed
# Sentence 183 completed
# Sentence 184 completed
# Sentence 185 completed
# Sentence 186 completed
# Sentence 187 completed
# Sentence 188 completed
# Sentence 189 completed
# Sentence 190 completed
# Sentence 191 completed
# Sentence 192 completed
# Sentence 193 completed
# Sentence 194 completed
# Sentence 195 completed
# Sentence 196 completed
# Sentence 197 completed
# Sentence 198 completed
# Sentence 199 completed
# Sentence 200 completed
# Sentence 201 completed
# Sentence 202 completed
# Sentence 203 completed
# Sentence 204 completed
# Sentence 205 completed
# Sentence 206 completed
# Sentence 207 completed
# Sentence 208 completed
# Sentence 209 completed
# Sentence 210 completed
# Sentence 211 completed
# Sentence 212 completed
# Sentence 213 completed
# Sentence 214 completed
# Sentence 215 completed
# Sentence 216 completed
# Sentence 217 completed
# Sentence 218 completed
# Sentence 219 completed
# Sentence 220 completed
# Sentence 221 completed
# Sentence 222 completed
# Sentence 223 completed
# Sentence 224 completed
# Sentence 225 completed
# Sentence 226 completed
# Sentence 227 completed
# Sentence 228 completed
# Sentence 229 completed
# Sentence 230 completed
# Sentence 231 completed
# Sentence 232 completed
# Sentence 233 completed
# Sentence 234 completed
# Sentence 235 completed
# Sentence 236 completed
# Sentence 237 completed
# Sentence 238 completed
# Sentence 239 completed
# Sentence 240 completed
# Sentence 241 completed
# Sentence 242 completed
# Sentence 243 completed
# Sentence 244 completed
# Sentence 245 completed
# Sentence 246 completed
# Sentence 247 completed
# Sentence 248 completed
# Sentence 249 completed
# Sentence 250 completed
# Sentence 251 completed
# Sentence 252 completed
# Sentence 253 completed
# Sentence 254 completed
# Sentence 255 completed
# Sentence 256 completed
# Sentence 257 completed
# Sentence 258 completed
# Sentence 259 completed
# Sentence 260 completed
# Sentence 261 completed
# Sentence 262 completed
# Sentence 263 completed
# Sentence 264 completed
# Sentence 265 completed
# Sentence 266 completed
# Sentence 267 completed
# Sentence 268 completed
# Sentence 269 completed
# Sentence 270 completed
# Sentence 271 completed
# Sentence 272 completed
# Sentence 273 completed
# Sentence 274 completed
# Sentence 275 completed
# Sentence 276 completed
# Sentence 277 completed
# Sentence 278 completed
# Sentence 279 completed
# Sentence 280 completed
# Sentence 281 completed
# Sentence 282 completed
# Sentence 283 completed
# Sentence 284 completed
# Sentence 285 completed
# Sentence 286 completed
# Sentence 287 completed
# Sentence 288 completed
# Sentence 289 completed
# Sentence 290 completed
# Sentence 291 completed
# Sentence 292 completed
# Sentence 293 completed
# Sentence 294 completed
# Sentence 295 completed
# Sentence 296 completed
# Sentence 297 completed
# Sentence 298 completed
# Sentence 299 completed
# Sentence 300 completed
# Sentence 301 completed
# Sentence 302 completed
# Sentence 303 completed
# Sentence 304 completed
# Sentence 305 completed
# Sentence 306 completed
# Sentence 307 completed
# Sentence 308 completed
# Sentence 309 completed
# Sentence 310 completed
# Sentence 311 completed
# Sentence 312 completed
# Sentence 313 completed
# Sentence 314 completed
# Sentence 315 completed
# Sentence 316 completed
# Sentence 317 completed
# Sentence 318 completed
# Sentence 319 completed
# Sentence 320 completed
# Sentence 321 completed
# Sentence 322 completed
# Sentence 323 completed
# Sentence 324 completed
# Sentence 325 completed
# Sentence 326 completed
# Sentence 327 completed
# Sentence 328 completed
# Sentence 329 completed
# Sentence 330 completed
# Sentence 331 completed
# Sentence 332 completed
# Sentence 333 completed
# Sentence 334 completed
# Sentence 335 completed
# Sentence 336 completed
# Sentence 337 completed
# Sentence 338 completed
# Sentence 339 completed
# Sentence 340 completed
# Sentence 341 completed
# Sentence 342 completed
# Sentence 343 completed
# Sentence 344 completed
# Sentence 345 completed
# Sentence 346 completed
# Sentence 347 completed
# Sentence 348 completed
# Sentence 349 completed
# Sentence 350 completed
# Sentence 351 completed
# Sentence 352 completed
# Sentence 353 completed
# Sentence 354 completed
# Sentence 355 completed
# Sentence 356 completed
# Sentence 357 completed
# Sentence 358 completed
# Sentence 359 completed
# Sentence 360 completed
# Sentence 361 completed
# Sentence 362 completed
# Sentence 363 completed
# Sentence 364 completed
# Sentence 365 completed
# Sentence 366 completed
# Sentence 367 completed
# Sentence 368 completed
# Sentence 369 completed
# Sentence 370 completed
# Sentence 371 completed
# Sentence 372 completed
# Sentence 373 completed
# Sentence 374 completed
# Sentence 375 completed
# Sentence 376 completed
# Sentence 377 completed
# Sentence 378 completed
# Sentence 379 completed
# Sentence 380 completed
# Sentence 381 completed
# Sentence 382 completed
# Sentence 383 completed
# Sentence 384 completed
# Sentence 385 completed
# Sentence 386 completed
# Sentence 387 completed
# Sentence 388 completed
# Sentence 389 completed
# Sentence 390 completed
# Sentence 391 completed
# Sentence 392 completed
# Sentence 393 completed
# Sentence 394 completed
# Sentence 395 completed
# Sentence 396 completed
# Sentence 397 completed
# Sentence 398 completed
# Sentence 399 completed
# Sentence 400 completed
# Sentence 401 completed
# Sentence 402 completed
# Sentence 403 completed
# Sentence 404 completed
# Sentence 405 completed
# Sentence 406 completed
# Sentence 407 completed
# Sentence 408 completed
# Sentence 409 completed
# Sentence 410 completed
# Sentence 411 completed
# Sentence 412 completed
# Sentence 413 completed
# Sentence 414 completed
# Sentence 415 completed
# Sentence 416 completed
# Sentence 417 completed
# Sentence 418 completed
# Sentence 419 completed
# Sentence 420 completed
# Sentence 421 completed
# Sentence 422 completed
# Sentence 423 completed
# Sentence 424 completed
# Sentence 425 completed
# Sentence 426 completed
# Sentence 427 completed
# Sentence 428 completed
# Sentence 429 completed
# Sentence 430 completed
# Sentence 431 completed
# Sentence 432 completed
# Sentence 433 completed
# Sentence 434 completed
# Sentence 435 completed
# Sentence 436 completed
# Sentence 437 completed
# Sentence 438 completed
# Sentence 439 completed
# Sentence 440 completed
# Sentence 441 completed
# Sentence 442 completed
# Sentence 443 completed
# Sentence 444 completed
# Sentence 445 completed
# Sentence 446 completed
# Sentence 447 completed
# Sentence 448 completed
# Sentence 449 completed
# Sentence 450 completed
# Sentence 451 completed
# Sentence 452 completed
# Sentence 453 completed
# Sentence 454 completed
# Sentence 455 completed
# Sentence 456 completed
# Sentence 457 completed
# Sentence 458 completed
# Sentence 459 completed
# Sentence 460 completed
# Sentence 461 completed
# Sentence 462 completed
# Sentence 463 completed
# Sentence 464 completed
# Sentence 465 completed
# Sentence 466 completed
# Sentence 467 completed
# Sentence 468 completed
# Sentence 469 completed
# Sentence 470 completed
# Sentence 471 completed
# Sentence 472 completed
# Sentence 473 completed
# Sentence 474 completed
# Sentence 475 completed
# Sentence 476 completed
# Sentence 477 completed
# Sentence 478 completed
# Sentence 479 completed
# Sentence 480 completed
# Sentence 481 completed
# Sentence 482 completed
# Sentence 483 completed
# Sentence 484 completed
# Sentence 485 completed
# Sentence 486 completed
# Sentence 487 completed
# Sentence 488 completed
# Sentence 489 completed
# Sentence 490 completed
# Sentence 491 completed
# Sentence 492 completed
# Sentence 493 completed
# Sentence 494 completed
# Sentence 495 completed
# Sentence 496 completed
# Sentence 497 completed
# Sentence 498 completed
# Sentence 499 completed
# Sentence 500 completed
# Sentence 501 completed
# Sentence 502 completed
# Sentence 503 completed
# Sentence 504 completed
# Sentence 505 completed
# Sentence 506 completed
# Sentence 507 completed
# Sentence 508 completed
# Sentence 509 completed
# Sentence 510 completed
# Sentence 511 completed
# Sentence 512 completed
# Sentence 513 completed
# Sentence 514 completed
# Sentence 515 completed
# Sentence 516 completed
# Sentence 517 completed
# Sentence 518 completed
# Sentence 519 completed
# Sentence 520 completed
# Sentence 521 completed
# Sentence 522 completed
# Sentence 523 completed
# Sentence 524 completed
# Sentence 525 completed
# Sentence 526 completed
# Sentence 527 completed
# Sentence 528 completed
# Sentence 529 completed
# Sentence 530 completed
# Sentence 531 completed
# Sentence 532 completed
# Sentence 533 completed
# Sentence 534 completed
# Sentence 535 completed
# Sentence 536 completed
# Sentence 537 completed
# Sentence 538 completed
# Sentence 539 completed
# Sentence 540 completed
# Sentence 541 completed
# Sentence 542 completed
# Sentence 543 completed
# Sentence 544 completed
# Sentence 545 completed
# Sentence 546 completed
# Sentence 547 completed
# Sentence 548 completed
# Sentence 549 completed
# Sentence 550 completed
# Sentence 551 completed
# Sentence 552 completed
# Sentence 553 completed
# Sentence 554 completed
# Sentence 555 completed
# Sentence 556 completed
# Sentence 557 completed
# Sentence 558 completed
# Sentence 559 completed
# Sentence 560 completed
# Sentence 561 completed
# Sentence 562 completed
# Sentence 563 completed
# Sentence 564 completed
# Sentence 565 completed
# Sentence 566 completed
# Sentence 567 completed
# Sentence 568 completed
# Sentence 569 completed
# Sentence 570 completed
# Sentence 571 completed
# Sentence 572 completed
# Sentence 573 completed
# Sentence 574 completed
# Sentence 575 completed
# Sentence 576 completed
# Sentence 577 completed
# Sentence 578 completed
# Sentence 579 completed
# Sentence 580 completed
# Sentence 581 completed
# Sentence 582 completed
# Sentence 583 completed
# Sentence 584 completed
# Sentence 585 completed
# Sentence 586 completed
# Sentence 587 completed
# Sentence 588 completed
# Sentence 589 completed
# Sentence 590 completed
# Sentence 591 completed
# Sentence 592 completed
# Sentence 593 completed
# Sentence 594 completed
# Sentence 595 completed
# Sentence 596 completed
# Sentence 597 completed
# Sentence 598 completed
# Sentence 599 completed
# Sentence 600 completed
# Sentence 601 completed
# Sentence 602 completed
# Sentence 603 completed
# Sentence 604 completed
# Sentence 605 completed
# Sentence 606 completed
# Sentence 607 completed
# Sentence 608 completed
# Sentence 609 completed
# Sentence 610 completed
# Sentence 611 completed
# Sentence 612 completed
# Sentence 613 completed
# Sentence 614 completed
# Sentence 615 completed
# Sentence 616 completed
# Sentence 617 completed
# Sentence 618 completed
# Sentence 619 completed
# Sentence 620 completed
# Sentence 621 completed
# Sentence 622 completed
# Sentence 623 completed
# Sentence 624 completed
# Sentence 625 completed
# Sentence 626 completed
# Sentence 627 completed
# Sentence 628 completed
# Sentence 629 completed
# Sentence 630 completed
# Sentence 631 completed
# Sentence 632 completed
# Sentence 633 completed
# Sentence 634 completed
# Sentence 635 completed
# Sentence 636 completed
# Sentence 637 completed
# Sentence 638 completed
# Sentence 639 completed
# Sentence 640 completed
# Sentence 641 completed
# Sentence 642 completed
# Sentence 643 completed
# Sentence 644 completed
# Sentence 645 completed
# Sentence 646 completed
# Sentence 647 completed
# Sentence 648 completed
# Sentence 649 completed
# Sentence 650 completed
# Sentence 651 completed
# Sentence 652 completed
# Sentence 653 completed
# Sentence 654 completed
# Sentence 655 completed
# Sentence 656 completed
# Sentence 657 completed
# Sentence 658 completed
# Sentence 659 completed
# Sentence 660 completed
# Sentence 661 completed
# Sentence 662 completed
# Sentence 663 completed
# Sentence 664 completed
# Sentence 665 completed
# Sentence 666 completed
# Sentence 667 completed
# Sentence 668 completed
# Sentence 669 completed
# Sentence 670 completed
# Sentence 671 completed
# Sentence 672 completed
# Sentence 673 completed
# Sentence 674 completed
# Sentence 675 completed
# Sentence 676 completed
# Sentence 677 completed
# Sentence 678 completed
# Sentence 679 completed
# Sentence 680 completed
# Sentence 681 completed
# Sentence 682 completed
# Sentence 683 completed
# Sentence 684 completed
# Sentence 685 completed
# Sentence 686 completed
# Sentence 687 completed
# Sentence 688 completed
# Sentence 689 completed
# Sentence 690 completed
# Sentence 691 completed
# Sentence 692 completed
# Sentence 693 completed
# Sentence 694 completed
# Sentence 695 completed
# Sentence 696 completed
# Sentence 697 completed
# Sentence 698 completed
# Sentence 699 completed
# Sentence 700 completed
# Sentence 701 completed
# Sentence 702 completed
# Sentence 703 completed
# Sentence 704 completed
# Sentence 705 completed
# Sentence 706 completed
# Sentence 707 completed
# Sentence 708 completed
# Sentence 709 completed
# Sentence 710 completed
# Sentence 711 completed
# Sentence 712 completed
# Sentence 713 completed
# Sentence 714 completed
# Sentence 715 completed
# Sentence 716 completed
# Sentence 717 completed
# Sentence 718 completed
# Sentence 719 completed
# Sentence 720 completed
# Sentence 721 completed
# Sentence 722 completed
# Sentence 723 completed
# Sentence 724 completed
# Sentence 725 completed
# Sentence 726 completed
# Sentence 727 completed
# Sentence 728 completed
# Sentence 729 completed
# Sentence 730 completed
# Sentence 731 completed
# Sentence 732 completed
# Sentence 733 completed
# Sentence 734 completed
# Sentence 735 completed
# Sentence 736 completed
# Sentence 737 completed
# Sentence 738 completed
# Sentence 739 completed
# Sentence 740 completed
# Sentence 741 completed
# Sentence 742 completed
# Sentence 743 completed
# Sentence 744 completed
# Sentence 745 completed
# Sentence 746 completed
# Sentence 747 completed
# Sentence 748 completed
# Sentence 749 completed
# Sentence 750 completed
# Sentence 751 completed
# Sentence 752 completed
# Sentence 753 completed
# Sentence 754 completed
# Sentence 755 completed
# Sentence 756 completed
# Sentence 757 completed
# Sentence 758 completed
# Sentence 759 completed
# Sentence 760 completed
# Sentence 761 completed
# Sentence 762 completed
# Sentence 763 completed
# Sentence 764 completed
# Sentence 765 completed
# Sentence 766 completed
# Sentence 767 completed
# Sentence 768 completed
# Sentence 769 completed
# Sentence 770 completed
# Sentence 771 completed
# Sentence 772 completed
# Sentence 773 completed
# Sentence 774 completed
# Sentence 775 completed
# Sentence 776 completed
# Sentence 777 completed
# Sentence 778 completed
# Sentence 779 completed
# Sentence 780 completed
# Sentence 781 completed
# Sentence 782 completed
# Sentence 783 completed
# Sentence 784 completed
# Sentence 785 completed
# Sentence 786 completed
# Sentence 787 completed
# Sentence 788 completed
# Sentence 789 completed
# Sentence 790 completed
# Sentence 791 completed
# Sentence 792 completed
# Sentence 793 completed
# Sentence 794 completed
# Sentence 795 completed
# Sentence 796 completed
# Sentence 797 completed
# Sentence 798 completed
# Sentence 799 completed
# Sentence 800 completed
# Sentence 801 completed
# Sentence 802 completed
# Sentence 803 completed
# Sentence 804 completed
# Sentence 805 completed
# Sentence 806 completed
# Sentence 807 completed
# Sentence 808 completed
# Sentence 809 completed
# Sentence 810 completed
# Sentence 811 completed
# Sentence 812 completed
# Sentence 813 completed
# Sentence 814 completed
# Sentence 815 completed
# Sentence 816 completed
# Sentence 817 completed
# Sentence 818 completed
# Sentence 819 completed
# Sentence 820 completed
# Sentence 821 completed
# Sentence 822 completed
# Sentence 823 completed
# Sentence 824 completed
# Sentence 825 completed
# Sentence 826 completed
# Sentence 827 completed
# Sentence 828 completed
# Sentence 829 completed
# Sentence 830 completed
# Sentence 831 completed
# Sentence 832 completed
# Sentence 833 completed
# Sentence 834 completed
# Sentence 835 completed
# Sentence 836 completed
# Sentence 837 completed
# Sentence 838 completed
# Sentence 839 completed
# Sentence 840 completed
# Sentence 841 completed
# Sentence 842 completed
# Sentence 843 completed
# Sentence 844 completed
# Sentence 845 completed
# Sentence 846 completed
# Sentence 847 completed
# Sentence 848 completed
# Sentence 849 completed
# Sentence 850 completed
# Sentence 851 completed
# Sentence 852 completed
# Sentence 853 completed
# Sentence 854 completed
# Sentence 855 completed
# Sentence 856 completed
# Sentence 857 completed
# Sentence 858 completed
# Sentence 859 completed
# Sentence 860 completed
# Sentence 861 completed
# Sentence 862 completed
# Sentence 863 completed
# Sentence 864 completed
# Sentence 865 completed
# Sentence 866 completed
# Sentence 867 completed
# Sentence 868 completed
# Sentence 869 completed
# Sentence 870 completed
# Sentence 871 completed
# Sentence 872 completed
# Sentence 873 completed
# Sentence 874 completed
# Sentence 875 completed
# Sentence 876 completed
# Sentence 877 completed
# Sentence 878 completed
# Sentence 879 completed
# Sentence 880 completed
# Sentence 881 completed
# Sentence 882 completed
# Sentence 883 completed
# Sentence 884 completed
# Sentence 885 completed
# Sentence 886 completed
# Sentence 887 completed
# Sentence 888 completed
# Sentence 889 completed
# Sentence 890 completed
# Sentence 891 completed
# Sentence 892 completed
# Sentence 893 completed
# Sentence 894 completed
# Sentence 895 completed
# Sentence 896 completed
# Sentence 897 completed
# Sentence 898 completed
# Sentence 899 completed
# Sentence 900 completed
# Sentence 901 completed
# Sentence 902 completed
# Sentence 903 completed
# Sentence 904 completed
# Sentence 905 completed
# Sentence 906 completed
# Sentence 907 completed
# Sentence 908 completed
# Sentence 909 completed
# Sentence 910 completed
# Sentence 911 completed
# Sentence 912 completed
# Sentence 913 completed
# Sentence 914 completed
# Sentence 915 completed
# Sentence 916 completed
# Sentence 917 completed
# Sentence 918 completed
# Sentence 919 completed
# Sentence 920 completed
# Sentence 921 completed
# Sentence 922 completed
# Sentence 923 completed
# Sentence 924 completed
# Sentence 925 completed
# Sentence 926 completed
# Sentence 927 completed
# Sentence 928 completed
# Sentence 929 completed
# Sentence 930 completed
# Sentence 931 completed
# Sentence 932 completed
# Sentence 933 completed
# Sentence 934 completed
# Sentence 935 completed
# Sentence 936 completed
# Sentence 937 completed
# Sentence 938 completed
# Sentence 939 completed
# Sentence 940 completed
# Sentence 941 completed
# Sentence 942 completed
# Sentence 943 completed
# Sentence 944 completed
# Sentence 945 completed
# Sentence 946 completed
# Sentence 947 completed
# Sentence 948 completed
# Sentence 949 completed
# Sentence 950 completed
# Sentence 951 completed
# Sentence 952 completed
# Sentence 953 completed
# Sentence 954 completed
# Sentence 955 completed
# Sentence 956 completed
# Sentence 957 completed
# Sentence 958 completed
# Sentence 959 completed
# Sentence 960 completed
# Sentence 961 completed
# Sentence 962 completed
# Sentence 963 completed
# Sentence 964 completed
# Sentence 965 completed
# Sentence 966 completed
# Sentence 967 completed
# Sentence 968 completed
# Sentence 969 completed
# Sentence 970 completed
# Sentence 971 completed
# Sentence 972 completed
# Sentence 973 completed
# Sentence 974 completed
# Sentence 975 completed
# Sentence 976 completed
# Sentence 977 completed
# Sentence 978 completed
# Sentence 979 completed
# Sentence 980 completed
# Sentence 981 completed
# Sentence 982 completed
# Sentence 983 completed
# Sentence 984 completed
# Sentence 985 completed
# Sentence 986 completed
# Sentence 987 completed
# Sentence 988 completed
# Sentence 989 completed
# Sentence 990 completed
# Sentence 991 completed
# Sentence 992 completed
# Sentence 993 completed
# Sentence 994 completed
# Sentence 995 completed
# Sentence 996 completed
# Sentence 997 completed
# Sentence 998 completed
# Sentence 999 completed
# Sentence 1000 completed
# Sentence 1001 completed
# Sentence 1002 completed
# Sentence 1003 completed
# Sentence 1004 completed
# Sentence 1005 completed
# Sentence 1006 completed
# Sentence 1007 completed
# Sentence 1008 completed
# Sentence 1009 completed
# Sentence 1010 completed
# Sentence 1011 completed
# Sentence 1012 completed
# Sentence 1013 completed
# Sentence 1014 completed
# Sentence 1015 completed
# Sentence 1016 completed
# Sentence 1017 completed
# Sentence 1018 completed
# Sentence 1019 completed
# Sentence 1020 completed
# Sentence 1021 completed
# Sentence 1022 completed
# Sentence 1023 completed
# Sentence 1024 completed
# Sentence 1025 completed
# Sentence 1026 completed
# Sentence 1027 completed
# Sentence 1028 completed
# Sentence 1029 completed
# Sentence 1030 completed
# Sentence 1031 completed
# Sentence 1032 completed
# Sentence 1033 completed
# Sentence 1034 completed
# Sentence 1035 completed
# Sentence 1036 completed
# Sentence 1037 completed
# Sentence 1038 completed
# Sentence 1039 completed
# Sentence 1040 completed
# Sentence 1041 completed
# Sentence 1042 completed
# Sentence 1043 completed
# Sentence 1044 completed
# Sentence 1045 completed
# Sentence 1046 completed
# Sentence 1047 completed
# Sentence 1048 completed
# Sentence 1049 completed
# Sentence 1050 completed
# Sentence 1051 completed
# Sentence 1052 completed
# Sentence 1053 completed
# Sentence 1054 completed
# Sentence 1055 completed
# Sentence 1056 completed
# Sentence 1057 completed
# Sentence 1058 completed
# Sentence 1059 completed
# Sentence 1060 completed
# Sentence 1061 completed
# Sentence 1062 completed
# Sentence 1063 completed
# Sentence 1064 completed
# Sentence 1065 completed
# Sentence 1066 completed
# Sentence 1067 completed
# Sentence 1068 completed
# Sentence 1069 completed
# Sentence 1070 completed
# Sentence 1071 completed
# Sentence 1072 completed
# Sentence 1073 completed
# Sentence 1074 completed
# Sentence 1075 completed
# Sentence 1076 completed
# Sentence 1077 completed
# Sentence 1078 completed
# Sentence 1079 completed
# Sentence 1080 completed
# Sentence 1081 completed
# Sentence 1082 completed
# Sentence 1083 completed
# Sentence 1084 completed
# Sentence 1085 completed
# Sentence 1086 completed
# Sentence 1087 completed
# Sentence 1088 completed
# Sentence 1089 completed
# Sentence 1090 completed
# Sentence 1091 completed
# Sentence 1092 completed
# Sentence 1093 completed
# Sentence 1094 completed
# Sentence 1095 completed
# Sentence 1096 completed
# Sentence 1097 completed
# Sentence 1098 completed
# Sentence 1099 completed
# Sentence 1100 completed
# Sentence 1101 completed
# Sentence 1102 completed
# Sentence 1103 completed
# Sentence 1104 completed
# Sentence 1105 completed
# Sentence 1106 completed
# Sentence 1107 completed
# Sentence 1108 completed
# Sentence 1109 completed
# Sentence 1110 completed
# Sentence 1111 completed
# Sentence 1112 completed
# Sentence 1113 completed
# Sentence 1114 completed
# Sentence 1115 completed
# Sentence 1116 completed
# Sentence 1117 completed
# Sentence 1118 completed
# Sentence 1119 completed
# Sentence 1120 completed
# Sentence 1121 completed
# Sentence 1122 completed
# Sentence 1123 completed
# Sentence 1124 completed
# Sentence 1125 completed
# Sentence 1126 completed
# Sentence 1127 completed
# Sentence 1128 completed
# Sentence 1129 completed
# Sentence 1130 completed
# Sentence 1131 completed
# Sentence 1132 completed
# Sentence 1133 completed
# Sentence 1134 completed
# Sentence 1135 completed
# Sentence 1136 completed
# Sentence 1137 completed
# Sentence 1138 completed
# Sentence 1139 completed
# Sentence 1140 completed
# Sentence 1141 completed
# Sentence 1142 completed
# Sentence 1143 completed
# Sentence 1144 completed
# Sentence 1145 completed
# Sentence 1146 completed
# Sentence 1147 completed
# Sentence 1148 completed
# Sentence 1149 completed
# Sentence 1150 completed
# Sentence 1151 completed
# Sentence 1152 completed
# Sentence 1153 completed
# Sentence 1154 completed
# Sentence 1155 completed
# Sentence 1156 completed
# Sentence 1157 completed
# Sentence 1158 completed
# Sentence 1159 completed
# Sentence 1160 completed
# Sentence 1161 completed
# Sentence 1162 completed
# Sentence 1163 completed
# Sentence 1164 completed
# Sentence 1165 completed
# Sentence 1166 completed
# Sentence 1167 completed
# Sentence 1168 completed
# Sentence 1169 completed
# Sentence 1170 completed
# Sentence 1171 completed
# Sentence 1172 completed
# Sentence 1173 completed
# Sentence 1174 completed
# Sentence 1175 completed
# Sentence 1176 completed
# Sentence 1177 completed
# Sentence 1178 completed
# Sentence 1179 completed
# Sentence 1180 completed
# Sentence 1181 completed
# Sentence 1182 completed
# Sentence 1183 completed
# Sentence 1184 completed
# Sentence 1185 completed
# Sentence 1186 completed
# Sentence 1187 completed
# Sentence 1188 completed
# Sentence 1189 completed
# Sentence 1190 completed
# Sentence 1191 completed
# Sentence 1192 completed
# Sentence 1193 completed
# Sentence 1194 completed
# Sentence 1195 completed
# Sentence 1196 completed
# Sentence 1197 completed
# Sentence 1198 completed
# Sentence 1199 completed
# Sentence 1200 completed
# Sentence 1201 completed
# Sentence 1202 completed
# Sentence 1203 completed
# Sentence 1204 completed
# Sentence 1205 completed
# Sentence 1206 completed
# Sentence 1207 completed
# Sentence 1208 completed
# Sentence 1209 completed
# Sentence 1210 completed
# Sentence 1211 completed
# Sentence 1212 completed
# Sentence 1213 completed
# Sentence 1214 completed
# Sentence 1215 completed
# Sentence 1216 completed
# Sentence 1217 completed
# Sentence 1218 completed
# Sentence 1219 completed
# Sentence 1220 completed
# Sentence 1221 completed
# Sentence 1222 completed
# Sentence 1223 completed
# Sentence 1224 completed
# Sentence 1225 completed
# Sentence 1226 completed
# Sentence 1227 completed
# Sentence 1228 completed
# Sentence 1229 completed
# Sentence 1230 completed
# Sentence 1231 completed
# Sentence 1232 completed
# Sentence 1233 completed
# Sentence 1234 completed
# Sentence 1235 completed
# Sentence 1236 completed
# Sentence 1237 completed
# Sentence 1238 completed
# Sentence 1239 completed
# Sentence 1240 completed
# Sentence 1241 completed
# Sentence 1242 completed
# Sentence 1243 completed
# Sentence 1244 completed
# Sentence 1245 completed
# Sentence 1246 completed
# Sentence 1247 completed
# Sentence 1248 completed
# Sentence 1249 completed
# Sentence 1250 completed
# Sentence 1251 completed
# Sentence 1252 completed
# Sentence 1253 completed
# Sentence 1254 completed
# Sentence 1255 completed
# Sentence 1256 completed
# Sentence 1257 completed
# Sentence 1258 completed
# Sentence 1259 completed
# Sentence 1260 completed
# Sentence 1261 completed
# Sentence 1262 completed
# Sentence 1263 completed
# Sentence 1264 completed
# Sentence 1265 completed
# Sentence 1266 completed
# Sentence 1267 completed
# Sentence 1268 completed
# Sentence 1269 completed
# Sentence 1270 completed
# Sentence 1271 completed
# Sentence 1272 completed
# Sentence 1273 completed
# Sentence 1274 completed
# Sentence 1275 completed
# Sentence 1276 completed
# Sentence 1277 completed
# Sentence 1278 completed
# Sentence 1279 completed
# Sentence 1280 completed
# Sentence 1281 completed
# Sentence 1282 completed
# Sentence 1283 completed
# Sentence 1284 completed
# Sentence 1285 completed
# Sentence 1286 completed
# Sentence 1287 completed
# Sentence 1288 completed
# Sentence 1289 completed
# Sentence 1290 completed
# Sentence 1291 completed
# Sentence 1292 completed
# Sentence 1293 completed
# Sentence 1294 completed
# Sentence 1295 completed
# Sentence 1296 completed
# Sentence 1297 completed
# Sentence 1298 completed
# Sentence 1299 completed
# Sentence 1300 completed
# Sentence 1301 completed
# Sentence 1302 completed
# Sentence 1303 completed
# Sentence 1304 completed
# Sentence 1305 completed
# Sentence 1306 completed
# Sentence 1307 completed
# Sentence 1308 completed
# Sentence 1309 completed
# Sentence 1310 completed
# Sentence 1311 completed
# Sentence 1312 completed
# Sentence 1313 completed
# Sentence 1314 completed
# Sentence 1315 completed
# Sentence 1316 completed
# Sentence 1317 completed
# Sentence 1318 completed
# Sentence 1319 completed
# Sentence 1320 completed
# Sentence 1321 completed
# Sentence 1322 completed
# Sentence 1323 completed
# Sentence 1324 completed
# Sentence 1325 completed
# Sentence 1326 completed
# Sentence 1327 completed
# Sentence 1328 completed
# Sentence 1329 completed
# Sentence 1330 completed
# Sentence 1331 completed
# Sentence 1332 completed
# Sentence 1333 completed
# Sentence 1334 completed
# Sentence 1335 completed
# Sentence 1336 completed
# Sentence 1337 completed
# Sentence 1338 completed
# Sentence 1339 completed
# Sentence 1340 completed
# Sentence 1341 completed
# Sentence 1342 completed
# Sentence 1343 completed
# Sentence 1344 completed
# Sentence 1345 completed
# Sentence 1346 completed
# Sentence 1347 completed
# Sentence 1348 completed
# Sentence 1349 completed
# Sentence 1350 completed
# Sentence 1351 completed
# Sentence 1352 completed
# Sentence 1353 completed
# Sentence 1354 completed
# Sentence 1355 completed
# Sentence 1356 completed
# Sentence 1357 completed
# Sentence 1358 completed
# Sentence 1359 completed
# Sentence 1360 completed
# Sentence 1361 completed
# Sentence 1362 completed
# Sentence 1363 completed
# Sentence 1364 completed
# Sentence 1365 completed
# Sentence 1366 completed
# Sentence 1367 completed
# Sentence 1368 completed
# Sentence 1369 completed
# Sentence 1370 completed
# Sentence 1371 completed
# Sentence 1372 completed
# Sentence 1373 completed
# Sentence 1374 completed
# Sentence 1375 completed
# Sentence 1376 completed
# Sentence 1377 completed
# Sentence 1378 completed
# Sentence 1379 completed
# Sentence 1380 completed
# Sentence 1381 completed
# Sentence 1382 completed
# Sentence 1383 completed
# Sentence 1384 completed
# Sentence 1385 completed
# Sentence 1386 completed
# Sentence 1387 completed
# Sentence 1388 completed
# Sentence 1389 completed
# Sentence 1390 completed
# Sentence 1391 completed
# Sentence 1392 completed
# Sentence 1393 completed
# Sentence 1394 completed
# Sentence 1395 completed
# Sentence 1396 completed
# Sentence 1397 completed
# Sentence 1398 completed
# Sentence 1399 completed
# Sentence 1400 completed
# Sentence 1401 completed
# Sentence 1402 completed
# Sentence 1403 completed
# Sentence 1404 completed
# Sentence 1405 completed
# Sentence 1406 completed
# Sentence 1407 completed
# Sentence 1408 completed
# Sentence 1409 completed
# Sentence 1410 completed
# Sentence 1411 completed
# Sentence 1412 completed
# Sentence 1413 completed
# Sentence 1414 completed
# Sentence 1415 completed
# Sentence 1416 completed
# Sentence 1417 completed
# Sentence 1418 completed
# Sentence 1419 completed
# Sentence 1420 completed
# Sentence 1421 completed
# Sentence 1422 completed
# Sentence 1423 completed
# Sentence 1424 completed
# Sentence 1425 completed
# Sentence 1426 completed
# Sentence 1427 completed
# Sentence 1428 completed
# Sentence 1429 completed
# Sentence 1430 completed
# Sentence 1431 completed
# Sentence 1432 completed
# Sentence 1433 completed
# Sentence 1434 completed
# Sentence 1435 completed
# Sentence 1436 completed
# Sentence 1437 completed
# Sentence 1438 completed
# Sentence 1439 completed
# Sentence 1440 completed
# Sentence 1441 completed
# Sentence 1442 completed
# Sentence 1443 completed
# Sentence 1444 completed
# Sentence 1445 completed
# Sentence 1446 completed
# Sentence 1447 completed
# Sentence 1448 completed
# Sentence 1449 completed
# Sentence 1450 completed
# Sentence 1451 completed
# Sentence 1452 completed
# Sentence 1453 completed
# Sentence 1454 completed
# Sentence 1455 completed
# Sentence 1456 completed
# Sentence 1457 completed
# Sentence 1458 completed
# Sentence 1459 completed
# Sentence 1460 completed
# Sentence 1461 completed
# Sentence 1462 completed
# Sentence 1463 completed
# Sentence 1464 completed
# Sentence 1465 completed
# Sentence 1466 completed
# Sentence 1467 completed
# Sentence 1468 completed
# Sentence 1469 completed
# Sentence 1470 completed
# Sentence 1471 completed
# Sentence 1472 completed
# Sentence 1473 completed
# Sentence 1474 completed
# Sentence 1475 completed
# Sentence 1476 completed
# Sentence 1477 completed
# Sentence 1478 completed
# Sentence 1479 completed
# Sentence 1480 completed
# Sentence 1481 completed
# Sentence 1482 completed
# Sentence 1483 completed
# Sentence 1484 completed
# Sentence 1485 completed
# Sentence 1486 completed
# Sentence 1487 completed
# Sentence 1488 completed
# Sentence 1489 completed
# Sentence 1490 completed
# Sentence 1491 completed
# Sentence 1492 completed
# Sentence 1493 completed
# Sentence 1494 completed
# Sentence 1495 completed
# Sentence 1496 completed
# Sentence 1497 completed
# Sentence 1498 completed
# Sentence 1499 completed
# Sentence 1500 completed
# Sentence 1501 completed
# Sentence 1502 completed
# Sentence 1503 completed
# Sentence 1504 completed
# Sentence 1505 completed
# Sentence 1506 completed
# Sentence 1507 completed
# Sentence 1508 completed
# Sentence 1509 completed
# Sentence 1510 completed
# Sentence 1511 completed
# Sentence 1512 completed
# Sentence 1513 completed
# Sentence 1514 completed
# Sentence 1515 completed
# Sentence 1516 completed
# Sentence 1517 completed
# Sentence 1518 completed
# Sentence 1519 completed
# Sentence 1520 completed
# Sentence 1521 completed
# Sentence 1522 completed
# Sentence 1523 completed
# Sentence 1524 completed
# Sentence 1525 completed
# Sentence 1526 completed
# Sentence 1527 completed
# Sentence 1528 completed
# Sentence 1529 completed
# Sentence 1530 completed
# Sentence 1531 completed
# Sentence 1532 completed
# Sentence 1533 completed
# Sentence 1534 completed
# Sentence 1535 completed
# Sentence 1536 completed
# Sentence 1537 completed
# Sentence 1538 completed
# Sentence 1539 completed
# Sentence 1540 completed
# Sentence 1541 completed
# Sentence 1542 completed
# Sentence 1543 completed
# Sentence 1544 completed
# Sentence 1545 completed
# Sentence 1546 completed
# Sentence 1547 completed
# Sentence 1548 completed
# Sentence 1549 completed
# Sentence 1550 completed
# Sentence 1551 completed
# Sentence 1552 completed
# Sentence 1553 completed
# Sentence 1554 completed
# Sentence 1555 completed
# Sentence 1556 completed
# Sentence 1557 completed
# Sentence 1558 completed
# Sentence 1559 completed
# Sentence 1560 completed
# Sentence 1561 completed
# Sentence 1562 completed
# Sentence 1563 completed
# Sentence 1564 completed
# Sentence 1565 completed
# Sentence 1566 completed
# Sentence 1567 completed
# Sentence 1568 completed
# Sentence 1569 completed
# Sentence 1570 completed
# Sentence 1571 completed
# Sentence 1572 completed
# Sentence 1573 completed
# Sentence 1574 completed
# Sentence 1575 completed
# Sentence 1576 completed
# Sentence 1577 completed
# Sentence 1578 completed
# Sentence 1579 completed
# Sentence 1580 completed
# Sentence 1581 completed
# Sentence 1582 completed
# Sentence 1583 completed
# Sentence 1584 completed
# Sentence 1585 completed
# Sentence 1586 completed
# Sentence 1587 completed
# Sentence 1588 completed
# Sentence 1589 completed
# Sentence 1590 completed
# Sentence 1591 completed
# Sentence 1592 completed
# Sentence 1593 completed
# Sentence 1594 completed
# Sentence 1595 completed
# Sentence 1596 completed
# Sentence 1597 completed
# Sentence 1598 completed
# Sentence 1599 completed
# Sentence 1600 completed
# Sentence 1601 completed
# Sentence 1602 completed
# Sentence 1603 completed
# Sentence 1604 completed
# Sentence 1605 completed
# Sentence 1606 completed
# Sentence 1607 completed
# Sentence 1608 completed
# Sentence 1609 completed
# Sentence 1610 completed
# Sentence 1611 completed
# Sentence 1612 completed
# Sentence 1613 completed
# Sentence 1614 completed
# Sentence 1615 completed
# Sentence 1616 completed
# Sentence 1617 completed
# Sentence 1618 completed
# Sentence 1619 completed
# Sentence 1620 completed
# Sentence 1621 completed
# Sentence 1622 completed
# Sentence 1623 completed
# Sentence 1624 completed
# Sentence 1625 completed
# Sentence 1626 completed
# Sentence 1627 completed
# Sentence 1628 completed
# Sentence 1629 completed
# Sentence 1630 completed
# Sentence 1631 completed
# Sentence 1632 completed
# Sentence 1633 completed
# Sentence 1634 completed
# Sentence 1635 completed
# Sentence 1636 completed
# Sentence 1637 completed
# Sentence 1638 completed
# Sentence 1639 completed
# Sentence 1640 completed
# Sentence 1641 completed
# Sentence 1642 completed
# Sentence 1643 completed
# Sentence 1644 completed
# Sentence 1645 completed
# Sentence 1646 completed
# Sentence 1647 completed
# Sentence 1648 completed
# Sentence 1649 completed
# Sentence 1650 completed
# Sentence 1651 completed
# Sentence 1652 completed
# Sentence 1653 completed
# Sentence 1654 completed
# Sentence 1655 completed
# Sentence 1656 completed
# Sentence 1657 completed
# Sentence 1658 completed
# Sentence 1659 completed
# Sentence 1660 completed
# Sentence 1661 completed
# Sentence 1662 completed
# Sentence 1663 completed
# Sentence 1664 completed
# Sentence 1665 completed
# Sentence 1666 completed
# Sentence 1667 completed
# Sentence 1668 completed
# Sentence 1669 completed
# Sentence 1670 completed
# Sentence 1671 completed
# Sentence 1672 completed
# Sentence 1673 completed
# Sentence 1674 completed
# Sentence 1675 completed
# Sentence 1676 completed
# Sentence 1677 completed
# Sentence 1678 completed
# Sentence 1679 completed
# Sentence 1680 completed
# Sentence 1681 completed
# Sentence 1682 completed
# Sentence 1683 completed
# Sentence 1684 completed
# Sentence 1685 completed
# Sentence 1686 completed
# Sentence 1687 completed
# Sentence 1688 completed
# Sentence 1689 completed
# Sentence 1690 completed
# Sentence 1691 completed
# Sentence 1692 completed
# Sentence 1693 completed
# Sentence 1694 completed
# Sentence 1695 completed
# Sentence 1696 completed
# Sentence 1697 completed
# Sentence 1698 completed
# Sentence 1699 completed
# Sentence 1700 completed
# Sentence 1701 completed
# Sentence 1702 completed
# Sentence 1703 completed
# Sentence 1704 completed
# Sentence 1705 completed
# Sentence 1706 completed
# Sentence 1707 completed
# Sentence 1708 completed
# Sentence 1709 completed
# Sentence 1710 completed
# Sentence 1711 completed
# Sentence 1712 completed
# Sentence 1713 completed
# Sentence 1714 completed
# Sentence 1715 completed
# Sentence 1716 completed
# Sentence 1717 completed
# Sentence 1718 completed
# Sentence 1719 completed
# Sentence 1720 completed
# Sentence 1721 completed
# Sentence 1722 completed
# Sentence 1723 completed
# Sentence 1724 completed
# Sentence 1725 completed
# Sentence 1726 completed
# Sentence 1727 completed
# Sentence 1728 completed
# Sentence 1729 completed
# Sentence 1730 completed
# Sentence 1731 completed
# Sentence 1732 completed
# Sentence 1733 completed
# Sentence 1734 completed
# Sentence 1735 completed
# Sentence 1736 completed
# Sentence 1737 completed
# Sentence 1738 completed
# Sentence 1739 completed
# Sentence 1740 completed
# Sentence 1741 completed
# Sentence 1742 completed
# Sentence 1743 completed
# Sentence 1744 completed
# Sentence 1745 completed
# Sentence 1746 completed
# Sentence 1747 completed
# Sentence 1748 completed
# Sentence 1749 completed
# Sentence 1750 completed
# Sentence 1751 completed
# Sentence 1752 completed
# Sentence 1753 completed
# Sentence 1754 completed
# Sentence 1755 completed
# Sentence 1756 completed
# Sentence 1757 completed
# Sentence 1758 completed
# Sentence 1759 completed
# Sentence 1760 completed
# Sentence 1761 completed
# Sentence 1762 completed
# Sentence 1763 completed
# Sentence 1764 completed
# Sentence 1765 completed
# Sentence 1766 completed
# Sentence 1767 completed
# Sentence 1768 completed
# Sentence 1769 completed
# Sentence 1770 completed
# Sentence 1771 completed
# Sentence 1772 completed
# Sentence 1773 completed
# Sentence 1774 completed
# Sentence 1775 completed
# Sentence 1776 completed
# Sentence 1777 completed
# Sentence 1778 completed
# Sentence 1779 completed
# Sentence 1780 completed
# Sentence 1781 completed
# Sentence 1782 completed
# Sentence 1783 completed
# Sentence 1784 completed
# Sentence 1785 completed
# Sentence 1786 completed
# Sentence 1787 completed
# Sentence 1788 completed
# Sentence 1789 completed
# Sentence 1790 completed
# Sentence 1791 completed
# Sentence 1792 completed
# Sentence 1793 completed
# Sentence 1794 completed
# Sentence 1795 completed
# Sentence 1796 completed
# Sentence 1797 completed
# Sentence 1798 completed
# Sentence 1799 completed
# Sentence 1800 completed
# Sentence 1801 completed
# Sentence 1802 completed
# Sentence 1803 completed
# Sentence 1804 completed
# Sentence 1805 completed
# Sentence 1806 completed
# Sentence 1807 completed
# Sentence 1808 completed
# Sentence 1809 completed
# Sentence 1810 completed
# Sentence 1811 completed
# Sentence 1812 completed
# Sentence 1813 completed
# Sentence 1814 completed
# Sentence 1815 completed
# Sentence 1816 completed
# Sentence 1817 completed
# Sentence 1818 completed
# Sentence 1819 completed
# Sentence 1820 completed
# Sentence 1821 completed
# Sentence 1822 completed
# Sentence 1823 completed
# Sentence 1824 completed
# Sentence 1825 completed
# Sentence 1826 completed
# Sentence 1827 completed
# Sentence 1828 completed
# Sentence 1829 completed
# Sentence 1830 completed
# Sentence 1831 completed
# Sentence 1832 completed
# Sentence 1833 completed
# Sentence 1834 completed
# Sentence 1835 completed
# Sentence 1836 completed
# Sentence 1837 completed
# Sentence 1838 completed
# Sentence 1839 completed
# Sentence 1840 completed
# Sentence 1841 completed
# Sentence 1842 completed
# Sentence 1843 completed
# Sentence 1844 completed
# Sentence 1845 completed
# Sentence 1846 completed
# Sentence 1847 completed
# Sentence 1848 completed
# Sentence 1849 completed
# Sentence 1850 completed
# Sentence 1851 completed
# Sentence 1852 completed
# Sentence 1853 completed
# Sentence 1854 completed
# Sentence 1855 completed
# Sentence 1856 completed
# Sentence 1857 completed
# Sentence 1858 completed
# Sentence 1859 completed
# Sentence 1860 completed
# Sentence 1861 completed
# Sentence 1862 completed
# Sentence 1863 completed
# Sentence 1864 completed
# Sentence 1865 completed
# Sentence 1866 completed
# Sentence 1867 completed
# Sentence 1868 completed
# Sentence 1869 completed
# Sentence 1870 completed
# Sentence 1871 completed
# Sentence 1872 completed
# Sentence 1873 completed
# Sentence 1874 completed
# Sentence 1875 completed
# Sentence 1876 completed
# Sentence 1877 completed
# Sentence 1878 completed
# Sentence 1879 completed
# Sentence 1880 completed
# Sentence 1881 completed
# Sentence 1882 completed
# Sentence 1883 completed
# Sentence 1884 completed
# Sentence 1885 completed
# Sentence 1886 completed
# Sentence 1887 completed
# Sentence 1888 completed
# Sentence 1889 completed
# Sentence 1890 completed
# Sentence 1891 completed
# Sentence 1892 completed
# Sentence 1893 completed
# Sentence 1894 completed
# Sentence 1895 completed
# Sentence 1896 completed
# Sentence 1897 completed
# Sentence 1898 completed
# Sentence 1899 completed
# Sentence 1900 completed
# Sentence 1901 completed
# Sentence 1902 completed
# Sentence 1903 completed
# Sentence 1904 completed
# Sentence 1905 completed
# Sentence 1906 completed
# Sentence 1907 completed
# Sentence 1908 completed
# Sentence 1909 completed
# Sentence 1910 completed
# Sentence 1911 completed
# Sentence 1912 completed
# Sentence 1913 completed
# Sentence 1914 completed
# Sentence 1915 completed
# Sentence 1916 completed
# Sentence 1917 completed
# Sentence 1918 completed
# Sentence 1919 completed
# Sentence 1920 completed
# Sentence 1921 completed
# Sentence 1922 completed
# Sentence 1923 completed
# Sentence 1924 completed
# Sentence 1925 completed
# Sentence 1926 completed
# Sentence 1927 completed
# Sentence 1928 completed
# Sentence 1929 completed
# Sentence 1930 completed
# Sentence 1931 completed
# Sentence 1932 completed
# Sentence 1933 completed
# Sentence 1934 completed
# Sentence 1935 completed
# Sentence 1936 completed
# Sentence 1937 completed
# Sentence 1938 completed
# Sentence 1939 completed
# Sentence 1940 completed
# Sentence 1941 completed
# Sentence 1942 completed
# Sentence 1943 completed
# Sentence 1944 completed
# Sentence 1945 completed
# Sentence 1946 completed
# Sentence 1947 completed
# Sentence 1948 completed
# Sentence 1949 completed
# Sentence 1950 completed
# Sentence 1951 completed
# Sentence 1952 completed
# Sentence 1953 completed
# Sentence 1954 completed
# Sentence 1955 completed
# Sentence 1956 completed
# Sentence 1957 completed
# Sentence 1958 completed
# Sentence 1959 completed
# Sentence 1960 completed
# Sentence 1961 completed
# Sentence 1962 completed
# Sentence 1963 completed
# Sentence 1964 completed
# Sentence 1965 completed
# Sentence 1966 completed
# Sentence 1967 completed
# Sentence 1968 completed
# Sentence 1969 completed
# Sentence 1970 completed
# Sentence 1971 completed
# Sentence 1972 completed
# Sentence 1973 completed
# Sentence 1974 completed
# Sentence 1975 completed
# Sentence 1976 completed
# Sentence 1977 completed
# Sentence 1978 completed
# Sentence 1979 completed
# Sentence 1980 completed
# Sentence 1981 completed
# Sentence 1982 completed
# Sentence 1983 completed
# Sentence 1984 completed
# Sentence 1985 completed
# Sentence 1986 completed
# Sentence 1987 completed
# Sentence 1988 completed
# Sentence 1989 completed
# Sentence 1990 completed
# Sentence 1991 completed
# Sentence 1992 completed
# Sentence 1993 completed
# Sentence 1994 completed
# Sentence 1995 completed
# Sentence 1996 completed
# Sentence 1997 completed
# Sentence 1998 completed
# Sentence 1999 completed
# Sentence 2000 completed
# Sentence 2001 completed
# Sentence 2002 completed
# Sentence 2003 completed
# Sentence 2004 completed
# Sentence 2005 completed
# Sentence 2006 completed
# Sentence 2007 completed
# Sentence 2008 completed
# Sentence 2009 completed
# Sentence 2010 completed
# Sentence 2011 completed
# Sentence 2012 completed
# Sentence 2013 completed
# Sentence 2014 completed
# Sentence 2015 completed
# Sentence 2016 completed
# Sentence 2017 completed
# Sentence 2018 completed
# Sentence 2019 completed
# Sentence 2020 completed
# Sentence 2021 completed
# Sentence 2022 completed
# Sentence 2023 completed
# Sentence 2024 completed
# Sentence 2025 completed
# Sentence 2026 completed
# Sentence 2027 completed
# Sentence 2028 completed
# Sentence 2029 completed
# Sentence 2030 completed
# Sentence 2031 completed
# Sentence 2032 completed
# Sentence 2033 completed
# Sentence 2034 completed
# Sentence 2035 completed
# Sentence 2036 completed
# Sentence 2037 completed
# Sentence 2038 completed
# Sentence 2039 completed
# Sentence 2040 completed
# Sentence 2041 completed
# Sentence 2042 completed
# Sentence 2043 completed
# Sentence 2044 completed
# Sentence 2045 completed
# Sentence 2046 completed
# ...
# Sentence 2335 completed
# Sentence 2336 completed
# Sentence 2337 completed
# Sentence 2338 completed
# Sentence 2339 completed
# Sentence 2340 completed
# Sentence 2341 completed
# Sentence 2342 completed
# Sentence 2343 completed
# Sentence 2344 completed
# Sentence 2345 completed
# Sentence 2346 completed
# Sentence 2347 completed
# Sentence 2348 completed
# Sentence 2349 completed
# Sentence 2350 completed
# Sentence 2351 completed
# Sentence 2352 completed
# Sentence 2353 completed
# Sentence 2354 completed
# Sentence 2355 completed
# Sentence 2356 completed
# Sentence 2357 completed
# Sentence 2358 completed
# Sentence 2359 completed
# Sentence 2360 completed
# Sentence 2361 completed
# Sentence 2362 completed
# Sentence 2363 completed
# Sentence 2364 completed
# Sentence 2365 completed
# Sentence 2366 completed
# Sentence 2367 completed
# Sentence 2368 completed
# Sentence 2369 completed
# Sentence 2370 completed
# Sentence 2371 completed
# Sentence 2372 completed
# Sentence 2373 completed
# Sentence 2374 completed
# Sentence 2375 completed
# Sentence 2376 completed
# Sentence 2377 completed
# Sentence 2378 completed
# Sentence 2379 completed
# Sentence 2380 completed
# Sentence 2381 completed
# Sentence 2382 completed
# Sentence 2383 completed
# Sentence 2384 completed
# Sentence 2385 completed
# Sentence 2386 completed
# Sentence 2387 completed
# Sentence 2388 completed
# Sentence 2389 completed
# Sentence 2390 completed
# Sentence 2391 completed
# Sentence 2392 completed
# Sentence 2393 completed
# Sentence 2394 completed
# Sentence 2395 completed
# Sentence 2396 completed
# Sentence 2397 completed
# Sentence 2398 completed
# Sentence 2399 completed
# Sentence 2400 completed
# Sentence 2401 completed
# Sentence 2402 completed
# Sentence 2403 completed
# Sentence 2404 completed
# Sentence 2405 completed
# Sentence 2406 completed
# Sentence 2407 completed
# Sentence 2408 completed
# Sentence 2409 completed
# Sentence 2410 completed
# Sentence 2411 completed
# Sentence 2412 completed
# Sentence 2413 completed
# Sentence 2414 completed
# Sentence 2415 completed
# Sentence 2416 completed
# Sentence 2417 completed
# Sentence 2418 completed
# Sentence 2419 completed
# Sentence 2420 completed
# Sentence 2421 completed
# Sentence 2422 completed
# Sentence 2423 completed
# Sentence 2424 completed
# Sentence 2425 completed
# Sentence 2426 completed
# Sentence 2427 completed
# Sentence 2428 completed
# Sentence 2429 completed
# Sentence 2430 completed
# Sentence 2431 completed
# Sentence 2432 completed
# Sentence 2433 completed
# Sentence 2434 completed
# Sentence 2435 completed
# Sentence 2436 completed
# Sentence 2437 completed
# Sentence 2438 completed
# Sentence 2439 completed
# Sentence 2440 completed
# Sentence 2441 completed
# Sentence 2442 completed
# Sentence 2443 completed
# Sentence 2444 completed
# Sentence 2445 completed
# Sentence 2446 completed
# Sentence 2447 completed
# Sentence 2448 completed
# Sentence 2449 completed
# Sentence 2450 completed
# Sentence 2451 completed
# Sentence 2452 completed
# Sentence 2453 completed
# Sentence 2454 completed
# Sentence 2455 completed
# Sentence 2456 completed
# Sentence 2457 completed
# Sentence 2458 completed
# Sentence 2459 completed
# Sentence 2460 completed
# Sentence 2461 completed
# Sentence 2462 completed
# Sentence 2463 completed
# Sentence 2464 completed
# Sentence 2465 completed
# Sentence 2466 completed
# Sentence 2467 completed
# Sentence 2468 completed
# Sentence 2469 completed
# Sentence 2470 completed
# Sentence 2471 completed
# Sentence 2472 completed
# Sentence 2473 completed
# Sentence 2474 completed
# Sentence 2475 completed
# Sentence 2476 completed
# Sentence 2477 completed
# Sentence 2478 completed
# Sentence 2479 completed
# Sentence 2480 completed
# Sentence 2481 completed
# Sentence 2482 completed
# Sentence 2483 completed
# Sentence 2484 completed
# Sentence 2485 completed
# Sentence 2486 completed
# Sentence 2487 completed
# Sentence 2488 completed
# Sentence 2489 completed
# Sentence 2490 completed
# Sentence 2491 completed
# Sentence 2492 completed
# Sentence 2493 completed
# Sentence 2494 completed
# Sentence 2495 completed
# Sentence 2496 completed
# Sentence 2497 completed
# Sentence 2498 completed
# Sentence 2499 completed
# Sentence 2500 completed
# Sentence 2501 completed
# Sentence 2502 completed
# Sentence 2503 completed
# Sentence 2504 completed
# Sentence 2505 completed
# Sentence 2506 completed
# Sentence 2507 completed
# Sentence 2508 completed
# Sentence 2509 completed
# Sentence 2510 completed
# Sentence 2511 completed
# Sentence 2512 completed
# Sentence 2513 completed
# Sentence 2514 completed
# Sentence 2515 completed
# Sentence 2516 completed
# Sentence 2517 completed
# Sentence 2518 completed
# Sentence 2519 completed
# Sentence 2520 completed
# Sentence 2521 completed
# Sentence 2522 completed
# Sentence 2523 completed
# Sentence 2524 completed
# Sentence 2525 completed
# Sentence 2526 completed
# Sentence 2527 completed
# Sentence 2528 completed
# Sentence 2529 completed
# Sentence 2530 completed
# Sentence 2531 completed
# Sentence 2532 completed
# Sentence 2533 completed
# Sentence 2534 completed
# Sentence 2535 completed
# Sentence 2536 completed
# Sentence 2537 completed
# Sentence 2538 completed
# Sentence 2539 completed
# Sentence 2540 completed
# Sentence 2541 completed
# Sentence 2542 completed
# Sentence 2543 completed
# Sentence 2544 completed
# Sentence 2545 completed
# Sentence 2546 completed
# Sentence 2547 completed
# Sentence 2548 completed
# Sentence 2549 completed
# Sentence 2550 completed
# Sentence 2551 completed
# Sentence 2552 completed
# Sentence 2553 completed
# Sentence 2554 completed
# Sentence 2555 completed
# Sentence 2556 completed
# Sentence 2557 completed
# Sentence 2558 completed
# Sentence 2559 completed
# Sentence 2560 completed
# Sentence 2561 completed
# Sentence 2562 completed
# Sentence 2563 completed
# Sentence 2564 completed
# Sentence 2565 completed
# Sentence 2566 completed
# Sentence 2567 completed
# Sentence 2568 completed
# Sentence 2569 completed
# Sentence 2570 completed
# Sentence 2571 completed
# Sentence 2572 completed
# Sentence 2573 completed
# Sentence 2574 completed
# Sentence 2575 completed
# Sentence 2576 completed
# Sentence 2577 completed
# Sentence 2578 completed
# Sentence 2579 completed
# Sentence 2580 completed
# Sentence 2581 completed
# Sentence 2582 completed
# Sentence 2583 completed
# Sentence 2584 completed
# Sentence 2585 completed
# Sentence 2586 completed
# Sentence 2587 completed
# Sentence 2588 completed
# Sentence 2589 completed
# Sentence 2590 completed
# Sentence 2591 completed
# Sentence 2592 completed
# Sentence 2593 completed
# Sentence 2594 completed
# Sentence 2595 completed
# Sentence 2596 completed
# Sentence 2597 completed
# Sentence 2598 completed
# Sentence 2599 completed
# Sentence 2600 completed
# Sentence 2601 completed
# Sentence 2602 completed
# Sentence 2603 completed
# Sentence 2604 completed
# Sentence 2605 completed
# Sentence 2606 completed
# Sentence 2607 completed
# Sentence 2608 completed
# Sentence 2609 completed
# Sentence 2610 completed
# Sentence 2611 completed
# Sentence 2612 completed
# Sentence 2613 completed
# Sentence 2614 completed
# Sentence 2615 completed
# Sentence 2616 completed
# Sentence 2617 completed
# Sentence 2618 completed
# Sentence 2619 completed
# Sentence 2620 completed
# Sentence 2621 completed
# Sentence 2622 completed
# Sentence 2623 completed
# Sentence 2624 completed
# Sentence 2625 completed
# Sentence 2626 completed
# Sentence 2627 completed
# Sentence 2628 completed
# Sentence 2629 completed
# Sentence 2630 completed
# Sentence 2631 completed
# Sentence 2632 completed
# Sentence 2633 completed
# Sentence 2634 completed
# Sentence 2635 completed
# Sentence 2636 completed
# Sentence 2637 completed
# Sentence 2638 completed
# Sentence 2639 completed
# Sentence 2640 completed
# Sentence 2641 completed
# Sentence 2642 completed
# Sentence 2643 completed
# Sentence 2644 completed
# Sentence 2645 completed
# Sentence 2646 completed
# Sentence 2647 completed
# Sentence 2648 completed
# Sentence 2649 completed
# Sentence 2650 completed
# Sentence 2651 completed
# Sentence 2652 completed
# Sentence 2653 completed
# Sentence 2654 completed
# Sentence 2655 completed
# Sentence 2656 completed
# Sentence 2657 completed
# Sentence 2658 completed
# Sentence 2659 completed
# Sentence 2660 completed
# Sentence 2661 completed
# Sentence 2662 completed
# Sentence 2663 completed
# Sentence 2664 completed
# Sentence 2665 completed
# Sentence 2666 completed
# Sentence 2667 completed
# Sentence 2668 completed
# Sentence 2669 completed
# Sentence 2670 completed
# Sentence 2671 completed
# Sentence 2672 completed
# Sentence 2673 completed
# Sentence 2674 completed
# Sentence 2675 completed
# Sentence 2676 completed
# Sentence 2677 completed
# Sentence 2678 completed
# Sentence 2679 completed
# Sentence 2680 completed
# Sentence 2681 completed
# Sentence 2682 completed
# Sentence 2683 completed
# Sentence 2684 completed
# Sentence 2685 completed
# Sentence 2686 completed
# Sentence 2687 completed
# Sentence 2688 completed
# Sentence 2689 completed
# Sentence 2690 completed
# Sentence 2691 completed
# Sentence 2692 completed
# Sentence 2693 completed
# Sentence 2694 completed
# Sentence 2695 completed
# Sentence 2696 completed
# Sentence 2697 completed
# Sentence 2698 completed
# Sentence 2699 completed
# Sentence 2700 completed
# Sentence 2701 completed
# Sentence 2702 completed
# Sentence 2703 completed
# Sentence 2704 completed
# Sentence 2705 completed
# Sentence 2706 completed
# Sentence 2707 completed
# Sentence 2708 completed
# Sentence 2709 completed
# Sentence 2710 completed
# Sentence 2711 completed
# Sentence 2712 completed
# Sentence 2713 completed
# Sentence 2714 completed
# Sentence 2715 completed
# Sentence 2716 completed
# Sentence 2717 completed
# Sentence 2718 completed
# Sentence 2719 completed
# Sentence 2720 completed
# Sentence 2721 completed
# Sentence 2722 completed
# Sentence 2723 completed
# Sentence 2724 completed
# Sentence 2725 completed
# Sentence 2726 completed
# Sentence 2727 completed
# Sentence 2728 completed
# Sentence 2729 completed
# Sentence 2730 completed
# Sentence 2731 completed
# Sentence 2732 completed
# Sentence 2733 completed
# Sentence 2734 completed
# Sentence 2735 completed
# Sentence 2736 completed
# Sentence 2737 completed
# Sentence 2738 completed
# Sentence 2739 completed
# Sentence 2740 completed
# Sentence 2741 completed
# Sentence 2742 completed
# Sentence 2743 completed
# Sentence 2744 completed
# Sentence 2745 completed
# Sentence 2746 completed
# Sentence 2747 completed
# Sentence 2748 completed
# Sentence 2749 completed
# Sentence 2750 completed
# Sentence 2751 completed
# Sentence 2752 completed
# Sentence 2753 completed
# Sentence 2754 completed
# Sentence 2755 completed
# Sentence 2756 completed
# Sentence 2757 completed
# Sentence 2758 completed
# Sentence 2759 completed
# Sentence 2760 completed
# Sentence 2761 completed
# Sentence 2762 completed
# Sentence 2763 completed
# Sentence 2764 completed
# Sentence 2765 completed
# Sentence 2766 completed
# Sentence 2767 completed
# Sentence 2768 completed
# Sentence 2769 completed
# Sentence 2770 completed
# Sentence 2771 completed
# Sentence 2772 completed
# Sentence 2773 completed
# Sentence 2774 completed
# Sentence 2775 completed
# Sentence 2776 completed
# Sentence 2777 completed
# Sentence 2778 completed
# Sentence 2779 completed
# Sentence 2780 completed
# Sentence 2781 completed
# Sentence 2782 completed
# Sentence 2783 completed
# Sentence 2784 completed
# Sentence 2785 completed
# Sentence 2786 completed
# Sentence 2787 completed
# Sentence 2788 completed
# Sentence 2789 completed
# Sentence 2790 completed
# Sentence 2791 completed
# Sentence 2792 completed
# Sentence 2793 completed
# Sentence 2794 completed
# Sentence 2795 completed
# Sentence 2796 completed
# Sentence 2797 completed
# Sentence 2798 completed
# Sentence 2799 completed
# Sentence 2800 completed
# Sentence 2801 completed
# Sentence 2802 completed
# Sentence 2803 completed
# Sentence 2804 completed
# Sentence 2805 completed
# Sentence 2806 completed
# Sentence 2807 completed
# Sentence 2808 completed
# Sentence 2809 completed
# Sentence 2810 completed
# Sentence 2811 completed
# Sentence 2812 completed
# Sentence 2813 completed
# Sentence 2814 completed
# Sentence 2815 completed
# Sentence 2816 completed
# Sentence 2817 completed
# Sentence 2818 completed
# Sentence 2819 completed
# Sentence 2820 completed
# Sentence 2821 completed
# Sentence 2822 completed
# Sentence 2823 completed
# Sentence 2824 completed
# Sentence 2825 completed
# Sentence 2826 completed
# Sentence 2827 completed
# Sentence 2828 completed
# Sentence 2829 completed
# Sentence 2830 completed
# Sentence 2831 completed
# Sentence 2832 completed
# Sentence 2833 completed
# Sentence 2834 completed
# Sentence 2835 completed
# Sentence 2836 completed
# Sentence 2837 completed
# Sentence 2838 completed
# Sentence 2839 completed
# Sentence 2840 completed
# Sentence 2841 completed
# Sentence 2842 completed
# Sentence 2843 completed
# Sentence 2844 completed
# Sentence 2845 completed
# Sentence 2846 completed
# Sentence 2847 completed
# Sentence 2848 completed
# Sentence 2849 completed
# Sentence 2850 completed
# Sentence 2851 completed
# Sentence 2852 completed
# Sentence 2853 completed
# Sentence 2854 completed
# Sentence 2855 completed
# Sentence 2856 completed
# Sentence 2857 completed
# Sentence 2858 completed
# Sentence 2859 completed
# Sentence 2860 completed
# Sentence 2861 completed
# Sentence 2862 completed
# Sentence 2863 completed
# Sentence 2864 completed
# Sentence 2865 completed
# Sentence 2866 completed
# Sentence 2867 completed
# Sentence 2868 completed
# Sentence 2869 completed
# Sentence 2870 completed
# Sentence 2871 completed
# Sentence 2872 completed
# Sentence 2873 completed
# Sentence 2874 completed
# Sentence 2875 completed
# Sentence 2876 completed
# Sentence 2877 completed
# Sentence 2878 completed
# Sentence 2879 completed
# Sentence 2880 completed
# Sentence 2881 completed
# Sentence 2882 completed
# Sentence 2883 completed
# Sentence 2884 completed
# Sentence 2885 completed
# Sentence 2886 completed
# Sentence 2887 completed
# Sentence 2888 completed
# Sentence 2889 completed
# Sentence 2890 completed
# Sentence 2891 completed
# Sentence 2892 completed
# Sentence 2893 completed
# Sentence 2894 completed
# Sentence 2895 completed
# Sentence 2896 completed
# Sentence 2897 completed
# Sentence 2898 completed
# Sentence 2899 completed
# Sentence 2900 completed
# Sentence 2901 completed
# Sentence 2902 completed
# Sentence 2903 completed
# Sentence 2904 completed
# Sentence 2905 completed
# Sentence 2906 completed
# Sentence 2907 completed
# Sentence 2908 completed
# Sentence 2909 completed
# Sentence 2910 completed
# Sentence 2911 completed
# Sentence 2912 completed
# Sentence 2913 completed
# Sentence 2914 completed
# Sentence 2915 completed
# Sentence 2916 completed
# Sentence 2917 completed
# Sentence 2918 completed
# Sentence 2919 completed
# Sentence 2920 completed
# Sentence 2921 completed
# Sentence 2922 completed
# Sentence 2923 completed
# Sentence 2924 completed
# Sentence 2925 completed
# Sentence 2926 completed
# Sentence 2927 completed
# Sentence 2928 completed
# Sentence 2929 completed
# Sentence 2930 completed
# Sentence 2931 completed
# Sentence 2932 completed
# Sentence 2933 completed
# Sentence 2934 completed
# Sentence 2935 completed
# Sentence 2936 completed
# Sentence 2937 completed
# Sentence 2938 completed
# Sentence 2939 completed
# Sentence 2940 completed
# Sentence 2941 completed
# Sentence 2942 completed
# Sentence 2943 completed
# Sentence 2944 completed
# Sentence 2945 completed
# Sentence 2946 completed
# Sentence 2947 completed
# Sentence 2948 completed
# Sentence 2949 completed
# Sentence 2950 completed
# Sentence 2951 completed
# Sentence 2952 completed
# Sentence 2953 completed
# Sentence 2954 completed
# Sentence 2955 completed
# Sentence 2956 completed
# Sentence 2957 completed
# Sentence 2958 completed
# Sentence 2959 completed
# Sentence 2960 completed
# Sentence 2961 completed
# Sentence 2962 completed
# Sentence 2963 completed
# Sentence 2964 completed
# Sentence 2965 completed
# Sentence 2966 completed
# Sentence 2967 completed
# Sentence 2968 completed
# Sentence 2969 completed
# Sentence 2970 completed
# Sentence 2971 completed
# Sentence 2972 completed
# Sentence 2973 completed
# Sentence 2974 completed
# Sentence 2975 completed
# Sentence 2976 completed
# Sentence 2977 completed
# Sentence 2978 completed
# Sentence 2979 completed
# Sentence 2980 completed
# Sentence 2981 completed
# Sentence 2982 completed
# Sentence 2983 completed
# Sentence 2984 completed
# Sentence 2985 completed
# Sentence 2986 completed
# Sentence 2987 completed
# Sentence 2988 completed
# Sentence 2989 completed
# Sentence 2990 completed
# Sentence 2991 completed
# Sentence 2992 completed
# Sentence 2993 completed
# Sentence 2994 completed
# Sentence 2995 completed
# Sentence 2996 completed
# Sentence 2997 completed
# Sentence 2998 completed
# Sentence 2999 completed
# Sentence 3000 completed

# %%
features1 = ["5_o_Clock_Shadow","Arched_Eyebrows","Attractive","Bags_Under_Eyes","Bald", "Bangs","Big_Lips","Big_Nose",
            "Black_Hair","Blond_Hair","Blurry","Brown_Hair","Bushy_Eyebrows","Chubby","Double_Chin","Eyeglasses","Goatee",
            "Gray_Hair", "Heavy_Makeup","High_Cheekbones","Male","Mouth_Slightly_Open","Mustache","Narrow_Eyes","No_Beard",
            "Oval_Face","Pale_Skin","Pointy_Nose","Receding_Hairline","Rosy_Cheeks","Sideburns","Smiling","Straight_Hair",
            "Wavy_Hair","Wearing_Earrings","Wearing_Hat","Wearing_Lipstick","Wearing_Necklace","Wearing_Necktie","Young"]

# %%
features1[32]
# Out:
# 'Straight_Hair'

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertModel
import pandas as pd
import torch.optim as optim

# %%
# Define the custom dataset class
class FacialFeatureDataset(Dataset):
    def __init__(self, sentences, features, tokenizer):
        self.sentences = sentences
        self.features = features
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, idx):
        sentence = self.sentences[idx]
        feature = self.features[idx]
        encoded_inputs = self.tokenizer.encode_plus(
            sentence,
            add_special_tokens=True,
            padding="max_length",
            truncation=True,
            max_length=128,
            return_tensors="pt",
        )
        return {
            "input_ids": encoded_inputs["input_ids"].squeeze(),
            "attention_mask": encoded_inputs["attention_mask"].squeeze(),
            "features": torch.tensor(feature, dtype=torch.float),
        }

# Define the transformer model with additional layers for classification
class FacialFeatureModel(nn.Module):
    def __init__(self, pretrained_model_name, num_features):
        super(FacialFeatureModel, self).__init__()
        self.bert = BertModel.from_pretrained(pretrained_model_name)
        self.classifier = nn.Linear(self.bert.config.hidden_size, num_features)

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.pooler_output
        logits = self.classifier(pooled_output)
        return logits

# Set random seed for reproducibility
torch.manual_seed(42)

# Load the dataset from the CSV file
df = pd.read_csv('sentences.csv')
sentences = df['sentence'].tolist()
features = df.iloc[:, 1:].values

# Split the dataset into train, validation, and test sets
train_sentences, test_sentences, train_features, test_features = train_test_split(
    sentences, features, test_size=0.2, random_state=42
)
train_sentences, val_sentences, train_features, val_features = train_test_split(
    train_sentences, train_features, test_size=0.1, random_state=42
)

# Initialize the tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Create dataset objects
train_dataset = FacialFeatureDataset(train_sentences, train_features, tokenizer)
val_dataset = FacialFeatureDataset(val_sentences, val_features, tokenizer)
test_dataset = FacialFeatureDataset(test_sentences, test_features, tokenizer)

# Define the batch size and number of training epochs
batch_size = 16
num_epochs = 10

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# Initialize the model and move it to the appropriate device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = FacialFeatureModel(pretrained_model_name='bert-base-uncased', num_features=40).to(device)

# Freeze the parameters of the BERT base model
for param in model.bert.parameters():
    param.requires_grad = False

# Define the optimizer and loss function
optimizer = optim.AdamW(model.classifier.parameters(), lr=2e-5)
criterion = nn.BCEWithLogitsLoss()

# Training loop
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
#visuals
import csv

filename = "C:/Users/yuceelege/Desktop/2023_Spring_Okul/NLP/Project/NLP-code/list_attr_celeba.csv"
features_list = []
counter = 0

with open(filename, 'r') as file:
    reader = csv.reader(file)
    next(reader)  # Skip the header row
    
    for row in reader:
        image_name = row[0]
        features = [int(value) for value in row[2:]]  # Convert binary values to integers
        #features_list.append(features)
        print(len(features))
        
        counter += 1
        if counter == 10:
            break
# Out:
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
